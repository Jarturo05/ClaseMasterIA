# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sra luz\appdata\local\programs\python\python311\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sra luz\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sra luz\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sra luz\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\sra luz\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

titanic = pd.read_csv("titanic_clase4.csv")
titanic
# Out:
#              nombre  sobrevivio  clase    sexo  edad  tarifa embarcacion  \
# 0       Jack Dawson           0      3    male  20.0    7.25           S
# 1       Rose DeWitt           1      1  female  17.0  512.33           C
# 2        John Smith           0      2    male  35.0   13.00           S
# 3      Mary Johnson           1      1  female  28.0   76.29           C
# 4      Thomas Brown           0      3    male   NaN    8.05           S
# 5   Elisabeth Jones           1      1  female  45.0   35.50           S
# 6     William Davis           0      3    male  23.0    7.92           Q
# 7      Sarah Wilson           1      2  female  31.0   21.00           S
# 8      James Miller           0      3    male   NaN    7.75           Q
# 9        Emma Moore           1      1  female  22.0  151.55           S
# 10    Robert Taylor           1      1    male  42.0   52.00           S
# 11    Anna Anderson           1      3  female  26.0    7.92           S
# 12  Charles Jackson           0      3    male  19.0    8.05           S
# 13   Margaret White           1      1  female  55.0   59.40           C
# 14    George Harris           0      3    male  29.0    7.25           S
# 15     Helen Martin           1      2  female  38.0   23.00           S
# 16  Edward Thompson           0      3    male   NaN    7.55           Q
# 17   Clara Robinson           1      1  female  33.0   83.15           C
# 18      Frank Lewis           0      3    male  40.0    9.50           S
# 19   Dorothy Walker           0      3  female  24.0    7.75           Q
# 20      Arthur Hall           0      3    male  36.0    7.25           S
# 21   Florence Allen           1      1  female  29.0  211.34           C
# 22      Henry Young           1      1    male  47.0   71.00           S
# 23    Beatrice King           1      3  female  21.0    8.43           S
# 24    Joseph Wright           0      3    male  33.0    7.92           Q
# 25      Mabel Scott           1      1  female  62.0   26.55           S
# 26     Walter Green           0      3    male   NaN    7.25           S
# 27      Alice Baker           1      2  female  27.0   21.00           C
# 28     Ernest Adams           0      3    male  44.0    8.05           S
# 29     Ethel Nelson           1      1  female  36.0  135.63           C
# 30       John Smith           0      2    male  35.0   13.00           S
#
#    cabina
# 0     NaN
# 1     B57
# 2     NaN
# 3     C85
# 4     NaN
# 5    C103
# 6     NaN
# 7     NaN
# 8     NaN
# 9     B45
# 10    C22
# 11    NaN
# 12    NaN
# 13    C68
# 14    NaN
# 15    NaN
# 16    NaN
# 17    E46
# 18    NaN
# 19    NaN
# 20    NaN
# 21    B30
# 22    C90
# 23    NaN
# 24    NaN
# 25   C101
# 26    NaN
# 27    NaN
# 28    NaN
# 29    B77
# 30    NaN

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nombre       31 non-null     str
#  1   sobrevivio   31 non-null     int64
#  2   clase        31 non-null     int64
#  3   sexo         31 non-null     str
#  4   edad         27 non-null     float64
#  5   tarifa       31 non-null     float64
#  6   embarcacion  31 non-null     str
#  7   cabina       11 non-null     str
# dtypes: float64(2), int64(2), str(4)
# memory usage: 2.1 KB

# %%
titanic.describe()
# Out:
#        sobrevivio      clase       edad      tarifa
# count   31.000000  31.000000  27.000000   31.000000
# mean     0.516129   2.129032  33.222222   52.375161
# std      0.508001   0.921663  11.056962   98.678691
# min      0.000000   1.000000  17.000000    7.250000
# 25%      0.000000   1.000000  25.000000    7.920000
# 50%      1.000000   2.000000  33.000000   13.000000
# 75%      1.000000   3.000000  39.000000   55.700000
# max      1.000000   3.000000  62.000000  512.330000

# %%
titanic.isnull().sum()
# Out:
# nombre          0
# sobrevivio      0
# clase           0
# sexo            0
# edad            4
# tarifa          0
# embarcacion     0
# cabina         20
# dtype: int64

# %%
titanic
# Out:
#              nombre  sobrevivio  clase    sexo  edad  tarifa embarcacion  \
# 0       Jack Dawson           0      3    male  20.0    7.25           S
# 1       Rose DeWitt           1      1  female  17.0  512.33           C
# 2        John Smith           0      2    male  35.0   13.00           S
# 3      Mary Johnson           1      1  female  28.0   76.29           C
# 4      Thomas Brown           0      3    male   NaN    8.05           S
# 5   Elisabeth Jones           1      1  female  45.0   35.50           S
# 6     William Davis           0      3    male  23.0    7.92           Q
# 7      Sarah Wilson           1      2  female  31.0   21.00           S
# 8      James Miller           0      3    male   NaN    7.75           Q
# 9        Emma Moore           1      1  female  22.0  151.55           S
# 10    Robert Taylor           1      1    male  42.0   52.00           S
# 11    Anna Anderson           1      3  female  26.0    7.92           S
# 12  Charles Jackson           0      3    male  19.0    8.05           S
# 13   Margaret White           1      1  female  55.0   59.40           C
# 14    George Harris           0      3    male  29.0    7.25           S
# 15     Helen Martin           1      2  female  38.0   23.00           S
# 16  Edward Thompson           0      3    male   NaN    7.55           Q
# 17   Clara Robinson           1      1  female  33.0   83.15           C
# 18      Frank Lewis           0      3    male  40.0    9.50           S
# 19   Dorothy Walker           0      3  female  24.0    7.75           Q
# 20      Arthur Hall           0      3    male  36.0    7.25           S
# 21   Florence Allen           1      1  female  29.0  211.34           C
# 22      Henry Young           1      1    male  47.0   71.00           S
# 23    Beatrice King           1      3  female  21.0    8.43           S
# 24    Joseph Wright           0      3    male  33.0    7.92           Q
# 25      Mabel Scott           1      1  female  62.0   26.55           S
# 26     Walter Green           0      3    male   NaN    7.25           S
# 27      Alice Baker           1      2  female  27.0   21.00           C
# 28     Ernest Adams           0      3    male  44.0    8.05           S
# 29     Ethel Nelson           1      1  female  36.0  135.63           C
# 30       John Smith           0      2    male  35.0   13.00           S
#
#    cabina
# 0     NaN
# 1     B57
# 2     NaN
# 3     C85
# 4     NaN
# 5    C103
# 6     NaN
# 7     NaN
# 8     NaN
# 9     B45
# 10    C22
# 11    NaN
# 12    NaN
# 13    C68
# 14    NaN
# 15    NaN
# 16    NaN
# 17    E46
# 18    NaN
# 19    NaN
# 20    NaN
# 21    B30
# 22    C90
# 23    NaN
# 24    NaN
# 25   C101
# 26    NaN
# 27    NaN
# 28    NaN
# 29    B77
# 30    NaN

# %%
# Merece la pena revisar nulos

# Se añade a una nueva variable y se borra la columna cabina
titanic_nuevo = titanic.drop(columns=["cabina"])

# Para eliminar los datos duplicados
titanic_nuevo = titanic_nuevo.drop_duplicates()

# Para hallar la meda de la edad y ponerla en las edades nulas
media_edad = titanic_nuevo["edad"].median()

#titanic_nievp["edad"] =
titanic_nuevo["edad"].fillna(media_edad)

print(f"Info Limpia: {titanic_nuevo}")
# Out:
# Info Limpia:              nombre  sobrevivio  clase    sexo  edad  tarifa embarcacion
# 0       Jack Dawson           0      3    male  20.0    7.25           S
# 1       Rose DeWitt           1      1  female  17.0  512.33           C
# 2        John Smith           0      2    male  35.0   13.00           S
# 3      Mary Johnson           1      1  female  28.0   76.29           C
# 4      Thomas Brown           0      3    male   NaN    8.05           S
# 5   Elisabeth Jones           1      1  female  45.0   35.50           S
# 6     William Davis           0      3    male  23.0    7.92           Q
# 7      Sarah Wilson           1      2  female  31.0   21.00           S
# 8      James Miller           0      3    male   NaN    7.75           Q
# 9        Emma Moore           1      1  female  22.0  151.55           S
# 10    Robert Taylor           1      1    male  42.0   52.00           S
# 11    Anna Anderson           1      3  female  26.0    7.92           S
# 12  Charles Jackson           0      3    male  19.0    8.05           S
# 13   Margaret White           1      1  female  55.0   59.40           C
# 14    George Harris           0      3    male  29.0    7.25           S
# 15     Helen Martin           1      2  female  38.0   23.00           S
# 16  Edward Thompson           0      3    male   NaN    7.55           Q
# 17   Clara Robinson           1      1  female  33.0   83.15           C
# 18      Frank Lewis           0      3    male  40.0    9.50           S
# 19   Dorothy Walker           0      3  female  24.0    7.75           Q
# 20      Arthur Hall           0      3    male  36.0    7.25           S
# 21   Florence Allen           1      1  female  29.0  211.34           C
# 22      Henry Young           1      1    male  47.0   71.00           S
# 23    Beatrice King           1      3  female  21.0    8.43           S
# 24    Joseph Wright           0      3    male  33.0    7.92           Q
# 25      Mabel Scott           1      1  female  62.0   26.55           S
# 26     Walter Green           0      3    male   NaN    7.25           S
# 27      Alice Baker           1      2  female  27.0   21.00           C
# 28     Ernest Adams           0      3    male  44.0    8.05           S
# 29     Ethel Nelson           1      1  female  36.0  135.63           C

# %%
tasa = titanic_nuevo["sobrevivio"].mean()
print(tasa)
print(f"Tasa de supervivencia es: {tasa:.0%}")


tasa = titanic["sobrevivio"].mean()
print(tasa)
print(f"Tasa de supervivencia es: {tasa:.0%}")
# Out:
# 0.5333333333333333
# Tasa de supervivencia es: 53%
# 0.5161290322580645
# Tasa de supervivencia es: 52%

# %%
titanic_nuevo.groupby("sexo")["sobrevivio"].mean()
# Out:
# sexo
# female    0.933333
# male      0.133333
# Name: sobrevivio, dtype: float64

# %%
titanic_nuevo.groupby("clase")["sobrevivio"].mean()
# Out:
# clase
# 1    1.000000
# 2    0.750000
# 3    0.133333
# Name: sobrevivio, dtype: float64

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/6f/d3/a4bbc01c237ab710a1f22b4da72f4ff6d77eb4c7735ea9811a94ae239067/matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      -------------- ----------------------- 20.5/52.8 kB 640.0 kB/s eta 0:00:01
#      ----------------------------- -------- 41.0/52.8 kB 487.6 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 546.1 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/98/4b/9bd370b004b5c9d8045c6c33cf65bae018b27aca550a3f657cdc99acdbd8/contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/d3/97/bf54c5b3f2be34e1f143e6db838dfdc54f2ffa3e68c738934c82f3b2a08d/fonttools-4.62.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading fonttools-4.62.1-cp311-cp311-win_amd64.whl.metadata (119 kB)
#      ---------------------------------------- 0.0/119.8 kB ? eta -:--:--
#      -------------------------------------- 119.8/119.8 kB 3.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/be/6c/28f17390b62b8f2f520e2915095b3c94d88681ecf0041e75389d9667f202/kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\sra luz\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\sra luz\appdata\roaming\python\python311\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/31/03/bef822e4f2d8f9d7448c133d0a18185d3cce3e70472774fffefe8b0ed562/pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Obtaining dependency information for pyparsing>=3 from https://files.pythonhosted.org/packages/10/bd/c038d7cc38edc1aa5bf91ab8068b63d4308c66c4c8bb3cbba7dfbc049f9c/pyparsing-3.3.2-py3-none-any.whl.metadata
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sra luz\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sra luz\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 9.8 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/8.1 MB 17.1 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/8.1 MB 20.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 26.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.1 MB 31.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 30.7 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    ---------------------------------------- 225.2/225.2 kB ? eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 75.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB ? eta 0:00:00
# Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------ --------------------------- 2.2/7.0 MB 47.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 56.2 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    ---------------------------------------- 122.8/122.8 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gráfica 1

# %%
supervivencia_sexo = titanic_nuevo.groupby("sexo")["sobrevivio"].mean()

plt.figure(figsize=(7, 5))
supervivencia_sexo.plot(
    kind="bar",
    color=["#D320B5","#3062B8"],
    edgecolor = "white",
    width=0.5
)

plt.title("Supervivencia por sexo", fontsize=14, fontweight="bold")

plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### Gráfica 2

# %%
supervivencia_clase = titanic_nuevo.groupby("clase")["sobrevivio"].mean()

plt.figure(figsize=(7, 5))
supervivencia_clase.plot(
    kind="bar",
    color=["#D320B5","#3062B8","#E64E12"],
    edgecolor = "white",
    width=0.5
)

plt.title("Supervivencia por clase", fontsize=14, fontweight="bold")
plt.xlabel("Clase", fontsize=14, fontweight="bold")
plt.ylabel("Tasa de supervivencia", fontsize=14, fontweight="bold")
# Out:
# Text(0, 0.5, 'Tasa de supervivencia')
