# %% [markdown]
# ## Taller integrador

# %%
# %pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/1f/67/af63f83cd6ca603a00fe8530c10a60f0879265b8be00b5930e8e78c5b30b/pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/76/1d/edccf27adedb754db7c4511d5eac8b83f004ae948fe2d3509e8b78097d4c/numpy-2.4.3-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tzdata from https://files.pythonhosted.org/packages/c7/b0/003792df09decd6849a5e39c28b513c06e84436a54440380862b5aeff25d/tzdata-2025.3-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 991.0 kB/s eta 0:00:10
#    -- ------------------------------------- 0.6/9.9 MB 7.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/9.9 MB 9.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

"print(pd.__version__)"

df = pd.read_csv("estudiantes.csv") 
df
# Out:
#     id            nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1       Laura Gómez    42      Medellín               0       8.3    True
# 1    2      Carlos Pérez    29          Cali               1       7.9    True
# 2    3        Anita Ruiz    40       Pereira               0       3.7    True
# 3    4       Juan Torres    29        Bogotá               8       4.8   False
# 4    5       María López    29     Manizales               4       8.8    True
# 5    6     Andrés Castro    27       Pereira               5       5.3    True
# 6    7     Sofía Herrera    32      Medellín               1       6.0    True
# 7    8    Diego Martínez    33     Cartagena               0       8.2    True
# 8    9    Valentina Ríos    34      Medellín               8       5.4    True
# 9   10       Felipe Mora    40  Barranquilla               1       3.8    True
# 10  11     Camila Vargas    31      Medellín               3       9.1   False
# ...

# %% [markdown]
# Pandas -> Libreria Python
# DataFrame -> Estructura que crea Pandas cuando carga un csv. Tiene por lo general filas y columnas

# %%
# Shape devuelve (fila, columnas)
print(df.shape)

# Nombres exactos de las columnas
print(df.columns.tolist())
# Out:
# (20, 7)
# ['id', 'nombre', 'edad', 'ciudad', 'cursos_previos', 'promedio', 'activo']

# %%
# Imprime la linea que se le pide a la lista
df["nombre"]
#df["edad"]
#df["ciudad"]
# Out:
# 0          Laura Gómez
# 1         Carlos Pérez
# 2           Anita Ruiz
# 3          Juan Torres
# 4          María López
# 5        Andrés Castro
# 6        Sofía Herrera
# 7       Diego Martínez
# 8       Valentina Ríos
# 9          Felipe Mora
# 10       Camila Vargas
# 11      Sebastián Díaz
# 12    Isabella Ramírez
# 13        Mateo Suárez
# 14     Lucía Fernández
# 15       Daniel Ortega
# 16    Gabriela Mendoza
# 17    Alejandro Flores
# 18       Natalia Reyes
# 19       Ricardo Rojas
# Name: nombre, dtype: str

# %%
# Para buscar un dato especifico de la lista
#print(df.loc[0, "nombre"])

#Para mostrar el ultimo nombre
print(df.loc[df.shape[0] -1, "nombre"])
# Out:
# Ricardo Rojas

# %%
# Mostrar los primeros 5 datos de la tabla
df.head()
# Out:
#    id        nombre  edad     ciudad  cursos_previos  promedio  activo
# 0   1   Laura Gómez    42   Medellín               0       8.3    True
# 1   2  Carlos Pérez    29       Cali               1       7.9    True
# 2   3    Anita Ruiz    40    Pereira               0       3.7    True
# 3   4   Juan Torres    29     Bogotá               8       4.8   False
# 4   5   María López    29  Manizales               4       8.8    True

# %%
# Metodo estadistico 
df.describe()
# Out:
#              id       edad  cursos_previos   promedio
# count  20.00000  20.000000       20.000000  20.000000
# mean   10.50000  34.100000        3.100000   6.705000
# std     5.91608   5.901828        2.531902   1.814409
# min     1.00000  27.000000        0.000000   3.700000
# 25%     5.75000  29.000000        1.000000   5.275000
# 50%    10.50000  32.500000        2.500000   6.650000
# 75%    15.25000  40.000000        5.000000   8.225000
# max    20.00000  45.000000        8.000000   9.300000

# %%
# Al momento de buscar datos en la tabla 
#df[(df["promedio"]>= 8.0)&(df["activo"] == True)]

# Se le agrega el nombre al final para que imprima solo los nombres de las personas que si cumplen con las condiciones
df[(df["promedio"] >= 8) & (df["activo"] == True)]["nombre"]
# Out:
# 0         Laura Gómez
# 4         María López
# 7      Diego Martínez
# 14    Lucía Fernández
# Name: nombre, dtype: str

# %% [markdown]
# ### Limpiar dataSet pero con criterio
#
# Detectar -> Hay algún problema?

# %%
# Importante cuando se llama a un metodo se encierra con ()
df.isnull().sum()
# Out:
# id                0
# nombre            0
# edad              0
# ciudad            0
# cursos_previos    0
# promedio          0
# activo            0
# dtype: int64

# %% [markdown]
# ### Se creo otro archivo para validar datos nulos

# %%
import pandas as pd

df = pd.read_csv("estudiantes_ml_2026_.csv") 
df
# Out:
#                nombre  edad            ciudad       pais genero nivel_previo  \
# 0    Valentina Torres    28            Bogotá   Colombia      F   intermedio
# 1      Carlos Mendoza    34  Ciudad de México     México      M       básico
# 2          Anita Ruiz    25          Medellín   Colombia      F       básico
# 3       Jorge Ramírez    41              Lima       Perú      M     avanzado
# 4        Daniela Soto    29          Santiago      Chile      F   intermedio
# 5       Miguel Flores    37       Guadalajara     México      M       básico
# 6         Laura Gómez    31              Cali   Colombia      F       básico
# 7    Sebastián Castro    26      Buenos Aires  Argentina      M   intermedio
# 8       Camila Vargas    33             Quito    Ecuador      F       básico
# 9      Andrés Herrera    45      Barranquilla   Colombia      M     avanzado
# 10      Paula Jiménez    27        Montevideo    Uruguay      F       básico
# ...

# %%
df.head()
# Out:
#              nombre  edad            ciudad      pais genero nivel_previo  \
# 0  Valentina Torres    28            Bogotá  Colombia      F   intermedio
# 1    Carlos Mendoza    34  Ciudad de México    México      M       básico
# 2        Anita Ruiz    25          Medellín  Colombia      F       básico
# 3     Jorge Ramírez    41              Lima      Perú      M     avanzado
# 4      Daniela Soto    29          Santiago     Chile      F   intermedio
#
#    horas_estudio_semana  promedio  modulos_completados  activo fecha_ingreso  \
# 0                    12       8.7                    3    True    2024-09-01
# 1                     8       5.2                    1    True    2024-09-01
# 2                    15       9.1                    3    True    2024-09-01
# 3                     6       7.4                    2    True    2024-09-01
# 4                    10       6.8                    2    True    2024-09-01
#
#    trabaja_actualmente  salario_usd            objetivo
# ...

# %%
# Detectar espacios nulos
df.isnull().sum()
# Out:
# nombre                  0
# edad                    0
# ciudad                  0
# pais                    0
# genero                  0
# nivel_previo            0
# horas_estudio_semana    0
# promedio                2
# modulos_completados     0
# activo                  0
# fecha_ingreso           0
# trabaja_actualmente     0
# salario_usd             0
# objetivo                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nombre                25 non-null     str
#  1   edad                  25 non-null     int64
#  2   ciudad                25 non-null     str
#  3   pais                  25 non-null     str
#  4   genero                25 non-null     str
#  5   nivel_previo          25 non-null     str
#  6   horas_estudio_semana  25 non-null     int64
#  7   promedio              23 non-null     float64
#  8   modulos_completados   25 non-null     int64
#  9   activo                25 non-null     bool
#  10  fecha_ingreso         25 non-null     str
#  11  trabaja_actualmente   25 non-null     bool
#  12  salario_usd           25 non-null     int64
#  13  objetivo              25 non-null     str
# dtypes: bool(2), float64(1), int64(4), str(7)
# memory usage: 2.5 KB
